# %%
import pandas as pd
import json
import sys
import os
import time
from tqdm import tqdm

# %%
from_file_path = "transfer_from.json"

transfer_from = json.load(open(from_file_path, "r"))

print("Loaded transfer_from")

to_file_path = "transfer_to.json"

transfer_to = json.load(open(to_file_path, "r"))

print("Loaded transfer_to")
# spark_from_df = spark.createDataFrame(from_df)
# Out:
# Loaded transfer_from
# Loaded transfer_to

# %%
from web3 import Web3
from datetime import datetime

# Replace 'your_infura_api_key' with your actual Infura API key or use your own Ethereum node
infura_url = "https://mainnet.infura.io/v3/b95e95d4ec4548c6b71c39a3793bce11"

# Connect to the Ethereum node
w3 = Web3(Web3.HTTPProvider(infura_url))

def convert_num2time(block_number):
    
    # Get the block information for the specified block number
    block = w3.eth.get_block(block_number)

    # Extract the timestamp from the block
    timestamp = block['timestamp']

    return timestamp

# %%
time_transfer_to = [
    {'id': item['id'], 'address': item['address'], 'time': item['receiving']['time']} for item in transfer_to]

# %%
time_transfer_from = [
    {'id': item['id'], 'address': item['address'], 'time': item['sending']['time']} for item in transfer_from]

# %%
time_transfer_to[3:5]
# Out:
# [{'id': '0x1_0x000000000004d7463d0f9c77383600bc82d612f5',
#   'address': '0x000000000004d7463d0f9c77383600bc82d612f5',
#   'time': [18096551, 18110297]},
#  {'id': '0x1_0x00000000001adc2c0b202d0f72ad9d50f0675296',
#   'address': '0x00000000001adc2c0b202d0f72ad9d50f0675296',
#   'time': [18068194]}]

# %%
time_transfer_from[3:5]
# Out:
# [{'id': '0x1_0x00000000003e04625c9001717346dd811ae5eba2',
#   'address': '0x00000000003e04625c9001717346dd811ae5eba2',
#   'time': [18592415, 18403008]},
#  {'id': '0x1_0x00000000005ef87f8ca7014309ece7260bbcdaeb',
#   'address': '0x00000000005ef87f8ca7014309ece7260bbcdaeb',
#   'time': [18145695]}]

# %%
distinct_from_id = [item['id'] for item in time_transfer_from]
print(len(distinct_from_id))
distinct_to_id = [item['id'] for item in time_transfer_to]
print(len(distinct_to_id))
# Out:
# 106834
# 129964

# %%
transfer_to[3:5]
# Out:
# [{'id': '0x1_0x000000000004d7463d0f9c77383600bc82d612f5',
#   'address': '0x000000000004d7463d0f9c77383600bc82d612f5',
#   'receiving': {'token': ['0x57b9d10157f66d8c00a815b5e289a152dedbe7ed'],
#    'amount': [1.6509999999999998],
#    'time': [18096551, 18110297],
#    'addresses': ['0xca520c87c3511ba475d3eb99624c844f89a897f8',
#     '0xe92fdd0d342eff7082ee5e447eb17df950fe9497']}},
#  {'id': '0x1_0x00000000001adc2c0b202d0f72ad9d50f0675296',
#   'address': '0x00000000001adc2c0b202d0f72ad9d50f0675296',
#   'receiving': {'token': ['0x28773a24699b20d01e9817550488f0db06477cc9'],
#    'amount': [3999.99],
#    'time': [18068194],
#    'addresses': ['0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48']}}]

# %%
transfer_from[3:5]
# Out:
# [{'id': '0x1_0x00000000003e04625c9001717346dd811ae5eba2',
#   'address': '0x00000000003e04625c9001717346dd811ae5eba2',
#   'sending': {'token': ['0x5f0e628b693018f639d10e4a4f59bd4d8b2b6b44',
#     '0xde7da3575cfb0324aeee5d1d48db0782d07eed62'],
#    'amount': [0.0866470313915537, 0.200343791766798],
#    'time': [18592415, 18403008],
#    'addresses': ['0x99835c99d579a05027f69d5a103717b2884c7a27',
#     '0x777777776ae22446a6d46b2fec86088ad553c0e1']}},
#  {'id': '0x1_0x00000000005ef87f8ca7014309ece7260bbcdaeb',
#   'address': '0x00000000005ef87f8ca7014309ece7260bbcdaeb',
#   'sending': {'token': ['0x3adb04e127b9c0a5d36094125669d4603ac52a0c'],
#    'amount': [1.989564096200543],
#    'time': [18145695],
#    'addresses': ['0xdcd8af1addb04179628956f9c086db1ff0d77522']}}]

# %%
distinct_from_id = [item['id'] for item in transfer_from]
print(len(distinct_from_id))
distinct_to_id = [item['id'] for item in transfer_to]
print(len(distinct_to_id))
# Out:
# 106834
# 129964

# %%
from tqdm import tqdm

merged_list = []

# Create a dictionary for quick lookup based on 'id' for transfer_from
dict_transfer_from = {item['id']: item for item in transfer_from}

# Use tqdm to track progress
for item1 in tqdm(transfer_to, desc='Merging Lists', unit='item'):
    item_id = item1['id']

    if item_id in dict_transfer_from:
        item2 = dict_transfer_from[item_id]

        # Merge the two dictionaries
        merged_item = {
            'id': item_id,
            'address': item1['address'],
            'sending': item2['sending'],
            'receiving': item1['receiving']
        }

        merged_list.append(merged_item)
    else:
        item1['sending'] = {'token': [],'amount': [],'time': [],'addresses': []}
        merged_list.append(item1)

# Add elements from transfer_from that are not present in transfer_to
for item2 in tqdm(transfer_from, desc='Adding Unmatched Items', unit='item'):
    item_id = item2['id']
    if item_id not in distinct_to_id:
        item2['receiving'] = {'token': [],'amount': [],'time': [],'addresses': []}                    
        merged_list.append(item2)
print(len(merged_list))
# Out:
# Merging Lists: 100%|█████████████████████████████████████████████████████| 129964/129964 [00:00<00:00, 241019.51item/s]
# Adding Unmatched Items: 100%|███████████████████████████████████████████████| 106834/106834 [13:38<00:00, 130.59item/s]
# 146451

# %%
merged_list[25]
# Out:
# {'id': '0x1_0x0000141eae0fd6d577e3c1702d19cb83c1943806',
#  'address': '0x0000141eae0fd6d577e3c1702d19cb83c1943806',
#  'sending': {'token': ['0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#    '0xde30da39c46104798bb5aa3fe8b9e0e1f348163f'],
#   'amount': [1.0, 5.46],
#   'time': [18133660, 18281452, 18281456],
#   'addresses': ['0x2021cf2bd16a3b17b0eefac6b98e134f4b1b0052',
#    '0xba87dc891945dbb3caeeaf822de208d7ea89b298']},
#  'receiving': {'token': ['0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'],
#   'amount': [1.0],
#   'time': [18281445],
#   'addresses': ['0xaaf5110db6e744ff70fb339de037b990a20bdace']}}

# %%
block_num = []

for element in tqdm(merged_list, desc='Extracting Block Numbers', unit='item'):
    block_dict = {
        "id": element['id'],
        "user": element['address'],
        "block_timestamp_list": element['sending']['time'] + element['receiving']['time']
    }
    block_num.append(block_dict)

print(len(block_num))
# Out:
# Extracting Block Numbers: 100%|███████████████████████████████████████████| 146451/146451 [00:02<00:00, 58362.06item/s]
# 146451

# %%
block_num[25]
# Out:
# {'id': '0x1_0x0000141eae0fd6d577e3c1702d19cb83c1943806',
#  'user': '0x0000141eae0fd6d577e3c1702d19cb83c1943806',
#  'block_timestamp_list': [18133660, 18281452, 18281456, 18281445]}

# %%
for i in tqdm(range(len(block_num)), desc='Convert Block Numbers', unit='item'):
    block_num[i]["block_timestamp_list"] = [conver_num2time(j) for j in block_num[i]["block_timestamp_list"]]

block_num[25]
# Out:
# Convert Block Numbers:   0%|                                                              | 0/146451 [00:11<?, ?item/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-5cd1b7401f27> in <module>
#       1 for i in tqdm(range(len(block_num)), desc='Convert Block Numbers', unit='item'):
# ----> 2     block_num[i]["block_timestamp_list"] = [conver_num2time(j) for j in block_num[i]["block_timestamp_list"]]
#       3
#       4 block_num[25]
#
# <ipython-input-56-5cd1b7401f27> in <listcomp>(.0)
#       1 for i in tqdm(range(len(block_num)), desc='Convert Block Numbers', unit='item'):
# ----> 2     block_num[i]["block_timestamp_list"] = [conver_num2time(j) for j in block_num[i]["block_timestamp_list"]]
#       3
#       4 block_num[25]
#
# <ipython-input-52-88d9ddfc9ebb> in conver_num2time(block_number)
#      13
#      14     # Get the block information for the specified block number
# ---> 15     block = w3.eth.get_block(block_number)
#      16
#      17     # Extract the timestamp from the block
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\web3\eth\eth.py in get_block(self, block_identifier, full_transactions)
#     388         self, block_identifier: BlockIdentifier, full_transactions: bool = False
#     389     ) -> BlockData:
# --> 390         return self._get_block(block_identifier, full_transactions)
#     391
#     392     # eth_getBalance
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\web3\module.py in caller(*args, **kwargs)
#      73             null_result_formatters,
#      74         ) = response_formatters
# ---> 75         result = w3.manager.request_blocking(
#      76             method_str, params, error_formatters, null_result_formatters
#      77         )
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\web3\manager.py in request_blocking(self, method, params, error_formatters, null_result_formatters)
#     322         Make a synchronous request using the provider
#     323         """
# --> 324         response = self._make_request(method, params)
#     325         return self.formatted_response(
#     326             response, params, error_formatters, null_result_formatters
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\web3\manager.py in _make_request(self, method, params)
#     210         )
#     211         self.logger.debug(f"Making request. Method: {method}")
# --> 212         return request_func(method, params)
#     213
#     214     async def _coro_make_request(
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\web3\middleware\gas_price_strategy.py in middleware(method, params)
#      99             )
#     100             return make_request(method, (transaction,))
# --> 101         return make_request(method, params)
#     102
#     103     return middleware
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\web3\middleware\formatting.py in middleware(method, params)
#     124                 formatter = request_formatters[method]
#     125                 params = formatter(params)
# --> 126             response = make_request(method, params)
#     127
#     128             return _apply_response_formatters(
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\web3\middleware\attrdict.py in middleware(method, params)
#      41
#      42     def middleware(method: RPCEndpoint, params: Any) -> RPCResponse:
# ---> 43         response = make_request(method, params)
#      44
#      45         if "result" in response:
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\web3\middleware\formatting.py in middleware(method, params)
#     124                 formatter = request_formatters[method]
#     125                 params = formatter(params)
# --> 126             response = make_request(method, params)
#     127
#     128             return _apply_response_formatters(
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\web3\middleware\formatting.py in middleware(method, params)
#     124                 formatter = request_formatters[method]
#     125                 params = formatter(params)
# --> 126             response = make_request(method, params)
#     127
#     128             return _apply_response_formatters(
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\web3\middleware\buffered_gas_estimate.py in middleware(method, params)
#      41                 )
#      42                 return make_request(method, [transaction])
# ---> 43         return make_request(method, params)
#      44
#      45     return middleware
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\web3\middleware\exception_retry_request.py in middleware(method, params)
#     122             for i in range(retries):
#     123                 try:
# --> 124                     return make_request(method, params)
#     125                 except tuple(errors):
#     126                     if i < retries - 1:
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\web3\providers\rpc.py in make_request(self, method, params)
#      88         )
#      89         request_data = self.encode_rpc_request(method, params)
# ---> 90         raw_response = make_post_request(
#      91             self.endpoint_uri, request_data, **self.get_request_kwargs()
#      92         )
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\web3\_utils\request.py in make_post_request(endpoint_uri, data, *args, **kwargs)
#     112     endpoint_uri: URI, data: Union[bytes, Dict[str, Any]], *args: Any, **kwargs: Any
#     113 ) -> bytes:
# --> 114     response = get_response_from_post_request(endpoint_uri, data=data, *args, **kwargs)
#     115     response.raise_for_status()
#     116     return response.content
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\web3\_utils\request.py in get_response_from_post_request(endpoint_uri, *args, **kwargs)
#     105     kwargs.setdefault("timeout", DEFAULT_TIMEOUT)
#     106     session = cache_and_return_session(endpoint_uri)
# --> 107     response = session.post(endpoint_uri, *args, **kwargs)
#     108     return response
#     109
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\requests\sessions.py in post(self, url, data, json, **kwargs)
#     588         """
#     589
# --> 590         return self.request('POST', url, data=data, json=json, **kwargs)
#     591
#     592     def put(self, url, data=None, **kwargs):
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# c:\users\admin\appdata\local\programs\python\python38\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# c:\users\admin\appdata\local\programs\python\python38\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# c:\users\admin\appdata\local\programs\python\python38\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# c:\users\admin\appdata\local\programs\python\python38\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# c:\users\admin\appdata\local\programs\python\python38\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# c:\users\admin\appdata\local\programs\python\python38\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
block_number_list = []

for item in tqdm(merged_list, desc='Extracting Block Numbers', unit='item'):
    sending_times = item['sending']['time']
    receiving_times = item['receiving']['time']

    block_number_list.extend(sending_times)
    block_number_list.extend(receiving_times)

print(len(block_number_list))
# Out:
# Extracting Block Numbers: 100%|██████████████████████████████████████████| 146451/146451 [00:00<00:00, 174883.27item/s]
# 12486203

# %%
block_number_distinct_lst = list(set(block_number_list))

# %%
len(block_number_distinct_lst)
# Out:
# 595175

# %%
# Dump the list into the JSON file
with open("block_number_distinct_lst.json", 'w') as json_file:
    json.dump(block_number_distinct_lst, json_file)

print(f"The list has been dumped")
# Out:
# The list has been dumped

# %%
# %store block_num
# Out:
# Stored 'block_num' (list)

# %%
# %store -r

# %%
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient('mongodb://etlReaderAnalysis:etl_reader_analysis__Gr2rEVBXyPWzIrP@34.126.84.83:27017,34.142.204.61:27017,34.142.219.60:27017/')
db = client["ethereum_blockchain_etl"]  
collection = db["transactions"]

# %%
timestamp_lookup = []

batch_size = 50
for i in tqdm(range(0, len(block_number_distinct_lst), batch_size)):
    start = i
    if i + batch_size < len(block_number_distinct_lst):
        end = i + batch_size
    else:
        end = len(block_number_distinct_lst)
    pipeline = [
        {
            "$match": {
                "block_number": {
                    "$in": block_number_distinct_lst[start:end]
                }
            }
        },
        {
            "$group": {
                "_id": "$block_number",
                "block_timestamp": {"$first": "$block_timestamp"}
            }
        },
        {
            "$project": {
                "_id": 0,
                "block_number": "$_id",
                "block_timestamp": 1
            }
        }
    ]
    
    batch_result = list(collection.aggregate(pipeline))
    timestamp_lookup.extend(batch_result)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████|
#  18010367: 1693192199,
#  18010368: 1693192211,
#  18010369: 1693192223,
#  18010370: 1693192235,
#  18010371: 1693192247,
#  18010372: 1693192259,
#  18010373: 1693192271,
#  18010374: 1693192283,
#  18010375: 1693192295,
#  18010376: 1693192307,
#  18010377: 1693192319,
#  18010378: 1693192331,
#  18010379: 1693192343,
#  18010380: 1693192355,
#  18010381: 1693192367,
#  18010382: 1693192379,
#  18010383: 1693192391,
#  18010384: 1693192403,
#  18010385: 1693192415,
#  18010386: 1693192427,
#  18010387: 1693192439,
#  18010388: 1693192451,
#  18010389: 1693192463,
#  18010390: 1693192475,
#  18010391: 1693192487,
#  18010392: 1693192499,
#  18010393: 1693192511,
#  18010394: 1693192523,
#  18010395: 1693192535,
#  18010396: 1693192547,
#  18010397: 1693192559,
#  18010398: 1693192571,
#  18010399: 1693192583,
#  18010400: 1693192607,
#  18010401: 1693192619,
#  18010402: 1693192631,
#  18010403: 1693192643,
#  18010404: 1693192655,
#  18010405: 1693192667,
#  18010406: 1693192679,
#  18010407: 1693192691,
#  18010408: 1693192703,
#  18010409: 1693192715,
#  18010410: 1693192727,
#  18010411: 1693192739,
#  18010412: 1693192751,
#  18010413: 1693192763,
#  18010414: 1693192775,
#  18010415: 1693192787,
#  18010416: 1693192799,
#  18010417: 1693192811,
#  18010418: 1693192823,
#  18010419: 1693192835,
#  18010420: 1693192847,
#  18010421: 1693192859,
#  18010422: 1693192871,
#  18010423: 1693192883,
#  18010424: 1693192895,
#  18010425: 1693192907,
#  18010426: 1693192919,
#  18010427: 1693192931,
#  ...}

# %%
for element in block_num:
    element['block_timestamp_list'] = [timestamp_lookup_dict.get(block_number, None) for block_number in element['block_timestamp_list']]

# Print or use the updated block_num list
print(len(block_num))
# Out:
# 146451

# %%
block_num[25]
# Out:
# {'id': '0x1_0x0000141eae0fd6d577e3c1702d19cb83c1943806',
#  'user': '0x0000141eae0fd6d577e3c1702d19cb83c1943806',
#  'block_timestamp_list': [1694684099, 1696474379, 1696474427, 1696474295]}

# %%
# Dump the list into the JSON file
with open("transfer_frequency.json", 'w') as json_file:
    json.dump(block_num, json_file)

print(f"The list has been dumped")

# %%
transfer_info = []

for item in tqdm(merged_list, desc='info', unit='item'):
    id = item["id"]
    user = item["address"]
    for idx, asset in enumerate(item["sending"]["token"]):
        record = {}
        record["id"] = id
        record["user"] = user
        record["asset"] = asset
        record["amount"] = item["sending"]["amount"][idx]
        record["event_type"] = "transfer_event"
        record["volume_type"] = "sending_volume"
        transfer_info.append(record)
    for idx, asset in enumerate(item["receiving"]["token"]):
        record = {}
        record["id"] = id
        record["user"] = user
        record["asset"] = asset
        record["amount"] = item["receiving"]["amount"][idx]
        record["event_type"] = "transfer_event"
        record["volume_type"] = "receiving_volume"
        transfer_info.append(record)
# Out:
# info: 100%|███████████████████████████████████████████████████████████████| 146451/146451 [00:01<00:00, 96118.17item/s]

# %%
len(transfer_info)
# Out:
# 1383430

# %%
# Dump the list into the JSON file
with open("transfer_info.json", 'w') as json_file:
    json.dump(transfer_info, json_file)

print(f"The list has been dumped")
# Out:
# The list has been dumped
