# %%
import json
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colWidth", None)

# %%
with open("../data/projects.json", encoding="utf-8") as f:
    data = json.load(f)
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (1653, 81)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1653 entries, 0 to 1652
# Data columns (total 81 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   _id                         1653 non-null   object
#  1   name                        1653 non-null   object
#  2   tvl                         433 non-null    object
#  3   deployedChains              1632 non-null   object
#  4   subprojects                 375 non-null    object
#  5   idDefiLlama                 435 non-null    object
#  6   rankTVL                     367 non-null    float64
#  7   marketShare                 367 non-null    float64
#  8   sources                     1652 non-null   object
#  9   imgUrl                      1652 non-null   object
#  10  tvlChangeRate               328 non-null    object
#  11  tvlChangeLogs               432 non-null    object
#  12  id                          1653 non-null   object
# ...

# %%
df.sort_values("numberOfOwners", ascending=False)[["id", "numberOfOwners", "volume", "rankNFT", "numberOfItems"]].head(20)
# Out:
#                  id  numberOfOwners        volume  rankNFT  numberOfItems
# 779             ens        828351.0  11028.262983     80.0      3056773.0
# 608         rarible        224947.0     92.793600   1137.0       321441.0
# 870   cryptokitties        120706.0    272.606976    746.0      2023128.0
# 1056          enjin         57488.0    184.393000   1103.0       169583.0
# 180         gemesis         47324.0   1441.188355    317.0        94743.0
# 534        debridge         33748.0      8.418502   1425.0        34642.0
# 83          sandbox         24510.0  23656.467289     53.0       165280.0
# 857            zora         24498.0   1135.203660    335.0        30010.0
# 109          sorare         16682.0    123.908721    899.0       336537.0
# 588       otherdeed         15945.0  69520.045360     21.0        47715.0
# 164     prometheans         15347.0    457.464710    735.0        55863.0
# 705     makersplace         14622.0    456.527000    596.0        94799.0
# ...

# %%
ens cryptokitties sandbox otherdeed clonex

# %%
df[df["id"] == "sandbox"]
# Out:
#         _id         name  tvl deployedChains subprojects idDefiLlama  rankTVL  \
# 83  sandbox  The Sandbox  NaN    [0x89, 0x1]         NaN         NaN      NaN
#
#     marketShare sources  \
# 83          NaN   [nft]
#
#                                                                                                                               imgUrl  \
# 83  https://i.seadn.io/gae/SXH8tW1siikB80rwCRnjm1a5xM_MwTg9Xl9Db6mioIk9HIlDM09pVoSR7GKJgS6ulSUpgW9BDtMk_ePX_NKgO9A?w=500&auto=format
#
#    tvlChangeRate tvlChangeLogs       id  \
# 83           NaN           NaN  sandbox
#
# ...
