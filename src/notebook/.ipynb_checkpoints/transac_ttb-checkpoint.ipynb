# %%
import json
from collections import defaultdict
import pandas as pd

# %%
cd ..
# Out:
# C:\Users\Admin\Desktop\ALL I NEED\group21_problem4\centic_query

# %%
cd ..
# Out:
# C:\Users\Admin\Desktop\ALL I NEED\group21_problem4

# %%
with open("projects.json", encoding="utf-8") as f:
    kg = json.load(f)

# %%
df = pd.DataFrame(kg).explode("deployedChains")

# %%
df.sort_values("numberOfOwners", ascending=False)[["id", "numberOfOwners", "volume", "rankNFT", "numberOfItems"]].head(10)
# Out:
#                  id  numberOfOwners        volume  rankNFT  numberOfItems
# 779             ens        828351.0  11028.262983     80.0      3056773.0
# 608         rarible        224947.0     92.793600   1137.0       321441.0
# 870   cryptokitties        120706.0    272.606976    746.0      2023128.0
# 1056          enjin         57488.0    184.393000   1103.0       169583.0
# 180         gemesis         47324.0   1441.188355    317.0        94743.0
# 534        debridge         33748.0      8.418502   1425.0        34642.0
# 534        debridge         33748.0      8.418502   1425.0        34642.0
# 534        debridge         33748.0      8.418502   1425.0        34642.0
# 534        debridge         33748.0      8.418502   1425.0        34642.0
# 534        debridge         33748.0      8.418502   1425.0        34642.0

# %%
top_5_project = ['ens', 'cryptokitties', 'sandbox', 'otherdeed', 'clonex']

# %%
df.columns
# Out:
# Index(['_id', 'name', 'tvl', 'deployedChains', 'subprojects', 'idDefiLlama',
#        'rankTVL', 'marketShare', 'sources', 'imgUrl', 'tvlChangeRate',
#        'tvlChangeLogs', 'id', 'contract_addresses', 'idOpensea', 'price',
#        'volume', 'volumeChangeRate', 'numberOfOwners', 'numberOfItems',
#        'numberOfListedItems', 'rankNFT', 'marketShareNFT', 'priceChangeLogs',
#        'volumeChangeLogs', 'lastUpdatedAt', 'lastUpdated', 'category',
#        'tokenAddresses', 'description', 'links', 'symbol', 'infoChecked',
#        'idBinance', 'priceChangeRate', 'coinId', 'rankDefi', 'marketShareDefi',
#        'socialAccounts', 'capPerTVL', 'tvlByChains', 'tvlByChainsChangeLogs',
#        'contractAddresses', 'forkedFrom', 'idCMC', 'dexVolume', 'launchedAt',
#        'dexVolumeChangeLogs', 'spotVolume', 'derivativeVolume',
#        'spotVolumeChangeLogs', 'derivativeVolumeChangeLogs', 'rankExchange',
#        'marketShareExchange', 'tradingVolume', 'tradingVolumeChangeLogs',
# ...

# %%
top_5_project_df = df[df["id"].isin(top_5_project)][['id','contract_addresses','deployedChains']].iloc[1:6,]

# %%
top_5_project_df
# Out:
#                 id                                 contract_addresses  \
# 83         sandbox  [0xf5b88d0a85cc5d458c3d820bd80fb14fb243a2f6, 0...
# 587         clonex  [0x49cf6f5d44e70224e2e23fdcdd2c053f30ada28b, 0...
# 588      otherdeed       [0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258]
# 779            ens  [0xd7a029db2585553978190db5e85ec724aa4df23f, 0...
# 870  cryptokitties  [0x25c7b64a93eb1261e130ec21a3e9918caa38b611, 0...
#
#     deployedChains
# 83             0x1
# 587            0x1
# 588            0x1
# 779            0x1
# 870            0x1

# %%
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient('mongodb://etlReaderAnalysis:etl_reader_analysis__Gr2rEVBXyPWzIrP@34.126.84.83:27017,34.142.204.61:27017,34.142.219.60:27017/')
db = client["ethereum_blockchain_etl"]  
collection = db["transactions"]

# %%
top_5_project_df.iloc[4,1]
# Out:
# ['0x25c7b64a93eb1261e130ec21a3e9918caa38b611',
#  '0xafe9459dcab91dad2447d5a159091156749941fb',
#  '0xa10740ff9ff6852eac84cdcff9184e1d6d27c057',
#  '0x09fe5f0236f0ea5d930197dce254d77b04128075',
#  '0xb1690c08e213a35ed9bab7b318de14420fb57d8c',
#  '0x06012c8cf97bead5deae237070f9587f8e7a266d']

# %%
test_res = {}

# %%
# print("Start with row " + str(0))

# query = {"to_address": {"$in": top_5_project_df.iloc[0,1]}}

# # Find documents matching the query
# cursor = collection.find(query)

# print(cursor)

# # Initialize variables
# result = []

# # Iterate over the cursor
# for i, document in enumerate(cursor):
#     if i%50000 == 0:
#         print("50k Done")
#     result.append(document)

# # Convert the result to a DataFrame
# df = pd.DataFrame(result)

# from_add = list(set(df["from_address"].tolist()))

# test_res[top_5_project_df.iloc[0,0]] = from_add

# print("Done with row " + str(0))
# Out:
# Start with row 0
# ...
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done
# 50k Done

# %%
len(test_res['otherdeed'])
# Out:
# 100922

# %%
# Define the query
for i in range(0,1):
    print("Start with row " + str(i))
    
#     query = {"to_address": {"$in": top_5_project_df.iloc[i,1]}}

#     # Find documents matching the query
#     cursor = collection.find(query)

#     print(cursor)

    # Initialize variables
    # test_res[top_5_project_df.iloc[i,0]] = []
    
    try:
        pipeline = [
            {"$match": {"to_address": {"$in": top_5_project_df.iloc[i,1]}}},
            {"$group": {"_id": "$from_address"}}
        ]

        # Execute the aggregation pipeline
        distinct_from_addresses = list(collection.aggregate(pipeline, batchSize=1000, maxTimeMS=50000))

        # Extract the distinct values
        distinct_from_addresses_values = [item["_id"] for item in distinct_from_addresses]
        
        test_res[top_5_project_df.iloc[i,0]] = distinct_from_addresses

    except:
        # Handle the timeout exception
        print(f"Timeout occurred for batch, continuing to the next batch.")
        
    print("Done with row " + str(i))
# Out:
# Start with row 0
# Timeout occurred for batch, continuing to the next batch.
# Done with row 0

# %%
# Specify the file path
file_path = "participants.json"

# Save the dictionary to a JSON file
with open(file_path, 'w') as json_file:
    json.dump(test_res, json_file)

print(f'Dictionary saved to {file_path}')
# Out:
# Dictionary saved to participants.json

# %%
pip install jsonlines
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import json
from glob import glob

# Initialize an empty list to store _id values
all_files = []

# Loop through each file

file_path = "fancy.json"
with open(file_path, encoding="utf-8") as f:
    # Load JSON data from the file
    data = json.load(f)

    # Extract _id values and extend the list
    all_files.append(data)

# Print the resulting list of _id values
# print("Concatenated _id values:", all_ids)

# with open("1.1.6.json", encoding="utf-8") as f:
#     abc = json.load(f)

# %%
len(all_files[0])
# Out:
# 2715293

# %%
the_1_1_list = list(set([item['from_address'] for item in all_files[0]]))

# %%
len(the_1_1_list)
# Out:
# 82369

# %%
# Specify the path to your JSON file
json_file_path = "participants.json"

# Open the file and load its content into a dictionary
with open(json_file_path, 'r') as json_file:
    data_as_dict = json.load(json_file)

# Now, data_as_dict contains the content of the JSON file as a dictionary
# pd.DataFrame(data_as_dict).head(10)

# %%
data_as_dict[top_5_project_df.iloc[4,0]].extend(the_1_1_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b5c573c2a72b> in <module>
# ----> 1 data_as_dict[top_5_project_df.iloc[4,0]].extend(the_1_1_list)
#
# NameError: name 'the_1_1_list' is not defined

# %%
len(data_as_dict[top_5_project_df.iloc[4,0]])
# Out:
# 176878

# %%
data_as_dict.keys()
# Out:
# dict_keys(['clonex', 'otherdeed', 'ens', 'sandbox', 'cryptokitties'])

# %%
# Specify the file path
file_path = "participants.json"

# Save the dictionary to a JSON file
with open(file_path, 'w') as json_file:
    json.dump(data_as_dict, json_file)

print(f'Dictionary saved to {file_path}')
# Out:
# Dictionary saved to participants.json

# %%
db_lending_events = db["lending_events"]

# %%
lending = {}
batch_size = 50
for project in data_as_dict.keys():
    print("Start with " + project)
    i = 0
    res = []
    while i < len(data_as_dict[project]):
        start = i
        if i + batch_size < len(data_as_dict[project]):
            end = i + batch_size
        else:
            end = len(data_as_dict[project])
        # Define the aggregation pipeline
        try:
            query = {
                "user": {"$in": data_as_dict[project][start:end]}
            }

            # Execute the query
            result = db_lending_events.find(query)

            # Print the result
            for document in result:
                res.append(document)
            res_df = pd.DataFrame(res)
            lending[project] = res_df
            
            if i % 2000 == 0:
                print("Done {}%".format(end / len(data_as_dict[project]) * 100))

        except:
            # Handle the timeout exception
            print(f"Timeout occurred for batch {start}-{end}, continuing to the next batch.")
            print(start, end)

        i += batch_size
    print("Done with " + project)
# Out:
# Start with clonex
# Done 0.15699572971615172%
# Done 6.436824918362221%
# Done 12.71665410700829%
# Done 18.99648329565436%
# Done 25.27631248430043%
# Done 31.5561416729465%
# Done 37.835970861592564%
# Done 44.11580005023863%
# Done 50.395629238884695%
# Done 56.67545842753077%
# Done 62.95528761617683%
# Done 69.23511680482291%
# Done 75.51494599346897%
# Done 81.79477518211505%
# Done 88.07460437076111%
# Done 94.35443355940718%
# Done with clonex
# Start with otherdeed
# Done 0.04954272068804931%
# Done 2.0312515482100215%
# Done 4.012960375731994%
# Done 5.994669203253967%
# Done 7.976378030775938%
# Done 9.95808685829791%
# Done 11.939795685819883%
# Done 13.921504513341853%
# Done 15.903213340863829%
# Done 17.8849221683858%
# Done 19.866630995907773%
# Done 21.848339823429743%
# Done 23.830048650951717%
# Done 25.81175747847369%
# Done 27.79346630599566%
# Done 29.775175133517635%
# Done 31.756883961039605%
# Done 33.738592788561576%
# Done 35.720301616083546%
# ...

# %%
for keys in lending:
    print(keys)
# Out:
# clonex
# otherdeed
# ens
# sandbox
# cryptokitties

# %%
data_as_dict['cryptokitties']
# Out:
# ['0x7a346656e50e343531ba30743b257861ff9c75cd',
#  '0x139780c1e4392493a7f0c3b1476f63ab8903115d',
#  '0xad42bfb5d2a79d16ecf5154295c8e145d0ceddac',
#  '0x6640ea0a27df1a923ddf525a0b72b56d42f9221c',
#  '0x12d991febde783daa8b1c785e3033c7b22a00e69',
#  '0x1542f494a223eb73d6d2186063ad084627e7a12c',
#  '0x1e5061ede01799470cb36d89161dc20052d6e996',
#  '0x39efb622753b4cd56a0986a7b61a217ba2a050df',
#  '0x509db83c23d0cddc3bd49e7333c7d14140379e26',
#  '0xaa2f21ef80a135982f37b9e87b3a8cc3af1c4242',
#  '0xc09770388bf682b4b29d117b8c0b2366c372eb1a',
#  '0x55b36c630f5de386498367b8ab6a7505cf9aab3b',
#  '0x05973f5967d278769fe5b4cef04ded1b7f92f934',
#  '0x1748662af545ccd6c614d244913c33b35f87f2d5',
#  '0xe041293a1b9e1a35921cb2a270fafdd7f6ad95d5',
#  '0xcfc652eb757f821da8b8f6afa4358880225ee456',
#  '0x5ace49fb876a5f3b69f74affd4f15b7b1a905913',
#  '0x3eee1837e988ba0b8de8a22407f38c4eda65fe99',
#  '0x796ccca8f49a8d18ff004629becfdf21619d006b',
#  '0xb88194f9bcc5ec80cf80c163ca2b123917468793',
# ...

# %%
# Specify the file path
for project in lending:
    file_path = project + ".json"

    data_dict = lending[project].to_dict(orient='records')

    # Save the dictionary to a JSON file
    with open(file_path, 'w') as json_file:
        json.dump(data_dict, json_file)

    print(f'Dictionary saved to {file_path}')
# Out:
# Dictionary saved to clonex.json
# Dictionary saved to otherdeed.json
# Dictionary saved to ens.json
# Dictionary saved to sandbox.json
# Dictionary saved to cryptokitties.json

# %%
len(lending['sandbox'])
# Out:
# 204851

# %%
lending['clonex']
# Out:
#                                                   _id         amount  \
# 0   transaction_0x6613cca9423a7813fd1cd5100858fe94...   10102.469152
# 1   transaction_0x1c7f48c8bfa3bc1c3ad8f1cf149b92c4...  100000.000000
# 2   transaction_0x716e254ce59d476e32f5d335338ad082...    6000.000000
# 3   transaction_0x017ae07f2f6869efbc2f5f5d549054cf...   30644.021590
# 4   transaction_0xf9cb05812773336e189c0dce8b4f6ff6...    5000.000000
# 5   transaction_0x8fa7e536dcdfdfc7725b39fe6abacf7e...   15000.000000
# 6   transaction_0xb2fa57ad55fb180f12eff823baea7142...   10000.000000
# 7   transaction_0x9b5505dd4bc41efe12ec97daf55e8d8e...    7000.000000
# 8                                        13396994_419  100000.000000
# 9                                        14113166_176    6000.000000
# 10                                       14200428_225   30644.021590
# 11                                       14377383_230   10102.469152
# 12                                       14602186_660    5000.000000
# ...

# %%
res_df.columns
# Out:
# Index(['_id', 'amount', 'block_number', 'block_timestamp', 'contract_address',
#        'event_type', 'log_index', 'referral', 'reserve', 'transaction_hash',
#        'type', 'user', 'wallet', 'amount_in_usd', 'on_behalf_of',
#        'account_borrows', 'total_borrows', 'token_amount', 'repayer',
#        'decimal_of_reserve', 'price_of_reserve', 'to', 'borrowRateMode',
#        'borrow_rate', 'interest_rate_mode', 'use_atokens', 'liquidator',
#        'price_of_collateral_asset', 'collateral_asset', 'debt_asset',
#        'debt_to_cover', 'debt_to_cover_in_usd', 'liquidated_collateral_amount',
#        'liquidated_collateral_amount_in_usd', 'receive_atoken'],
#       dtype='object')

# %%
res_df[['amount', 'user', 'wallet', 'on_behalf_of', 'reserve', 'event_type', 'contract_address','to']]
# Out:
#            amount                                        user  \
# 0        5.000000  0x0317d91c89396c65de570c6a1a5ff8d5485c58dc
# 1        5.000000  0x0317d91c89396c65de570c6a1a5ff8d5485c58dc
# 2        2.000000  0x04afc5c09a6f06070c0cdbaf2b2604e371f50f41
# 3        0.300000  0x04afc5c09a6f06070c0cdbaf2b2604e371f50f41
# 4       90.000000  0x04afc5c09a6f06070c0cdbaf2b2604e371f50f41
# ...           ...                                         ...
# 3226  1826.233219  0xf7838c101dd142abff1b612bd4da21b21e43721f
# 3227  1918.059495  0xf7838c101dd142abff1b612bd4da21b21e43721f
# 3228   414.075568  0xf7838c101dd142abff1b612bd4da21b21e43721f
# 3229     3.166630  0xffc88fc868a01003fe5d3fcc389051a365d4f932
# 3230     3.173005  0xffc88fc868a01003fe5d3fcc389051a365d4f932
#
#                                           wallet  \
# 0     0x0317d91c89396c65de570c6a1a5ff8d5485c58dc
# 1     0x0317d91c89396c65de570c6a1a5ff8d5485c58dc
# 2     0x04afc5c09a6f06070c0cdbaf2b2604e371f50f41
# ...

# %%
set(res_df['event_type'])
# Out:
# {'BORROW',
#  'DEPOSIT',
#  'LIQUIDATE',
#  'REPAY',
#  'RESERVEUSEDASCOLLATERALDISABLED',
#  'RESERVEUSEDASCOLLATERALENABLED',
#  'WITHDRAW'}

# %%
df[['contract_addresses','_id','deployedChains']]
# Out:
#                                 contract_addresses                   _id  \
# 0     [0x78627c6798b9db51ca48dea1ff6ce0f5c5a66f81]  crystalfrogsofficial
# 1     [0x095dcca826ef15c8ac06088be7f5ff85c506191a]       hanazawakananft
# 2     [0xfe58fc763ba915013aee93c6f0890bfddbe03608]          beepboopbotz
# 3     [0x91673149ffae3274b32997288395d07a8213e41f]          junkyarddogs
# 4     [0x104f4986e647a5a3f4d1fdeae72e35f0c92ab484]         polarfrensnft
# ...                                            ...                   ...
# 1125  [0x9a38dec0590abc8c883d72e52391090e948ddf12]                everai
# 1126  [0xd24a7c412f2279b1901e591898c1e96c140be8c5]     patchworkkingdoms
# 1127  [0xa379cec69303e3ec0fea64d9298f126658276f63]           punks2hanzo
# 1128  [0x99c2546aebc070fb1f286a346ec4d25e70533474]              quadrums
# 1129  [0x33a4cfc925ad40e5bb2b9b2462d7a1a5a5da4476]                 pills
#
#      deployedChains
# 0               0x1
# 1               0x1
# 2               0x1
# ...

# %%
bnb_df = df[df['deployedChains']=='0x38'].reset_index()

# %%
bnb_df[['contract_addresses','_id','deployedChains']]
# Out:
#                                    contract_addresses           _id  \
# 0   [0x84e20e875b593578f6476b5280a3ea28d06c59fc, 0...          mdex
# 1   [0x6b0cc136f7babd971b5decd21690be65718990e2, 0...       apeswap
# 2   [0xfa8bfdcab049590cac0af3fd62c49570d892a4e2, 0...  openleverage
# 3   [0x4e352cf164e64adcbad318c3a1e222e9eba4ce42, 0...         mcdex
# 4   [0x68dda7c12f792e17c747a627d41153c103310d74, 0...          cone
# 5   [0x05894b0c44f8bb067885f97e53acbdbe6d9987c1, 0...       apollox
# 6   [0x4d9bbf4a1f3c663c060edd694466003fa71fa68f, 0...    secondlive
# 7   [0x79302f3f681e47611207fdb2e6a172ae27653e7c, 0...      swapfish
# 8        [0x17e65e6b9b166fb8e7c59432f0db126711246bc0]          tifi
# 9   [0xbf365ce9cfcb2d5855521985e351ba3bcf77fd3f, 0...         woofi
# 10       [0x668ad0ed2622c62e24f0d5ab6b6ac1b9d2cd4ac7]       jetswap
# 11  [0x8485c5f255ff30aafab0030329e508bd8dde11c5, 0...    wardenswap
# 12       [0x066798d9ef0833ccc719076dab77199ecbd178b0]      sakeperp
# ...

# %%
exploded_bnb_df = bnb_df.explode('contract_addresses')

# %%
aggregated_bnb_list = exploded_bnb_df['contract_addresses'].tolist()
aggregated_bnb_list
# Out:
# ['0x84e20e875b593578f6476b5280a3ea28d06c59fc',
#  '0xbb27766c4b6ab62d04ff6bc3c4c8a0b53ec42adf',
#  '0x0017a8a1e6230f55e433866bde5aff81f91f2fe3',
#  '0x00221b0254bb3aad813aceac781f7743765740a1',
#  '0x0025d20d85788c2cae2feb9c298bdafc93bf08ce',
#  '0x00309bf7efa78b79888ab413e1231dfc008e467b',
#  '0x00717be6b9028b60a1da6c31ae21be14ff4b5af3',
#  '0x01138d82d68f5f4ee5aea25c58c486f79d890055',
#  '0x015363fb4fe03ade0bc0cf2beeeb7bfb7ed82f14',
#  '0x0154916f25e8433591632bd4839f364e6b0a2033',
#  '0x01681f62ece999249f4c188748746ada1619178f',
#  '0x01718ba7146645118895972eb7f4fa951a5a8fb0',
#  '0x017290a11903779eb4b521c8f7941afaf6c2d9b1',
#  '0x01e5a7b334dbd4aa259b644e3dfb5a4a3e4867a9',
#  '0x02033a7362bdacf1661fbdfc5f9a187392adfbf0',
#  '0x021f4ff02e98dedcbdef63dc895373a793c98981',
#  '0x02532545fdb6b6cf0e63cb5d69c8f9449d057d11',
#  '0x026ebdb39666924997a71bafb7e48c7250cec9ba',
#  '0x028bb0fe4070e37679fecd20a2c751cb5c2afc81',
#  '0x029021628d5fe0e62881813c08d4b988499cc3b9',
# ...

# %%
file_path = 'output_bnb.txt'

# Write the list elements to the text file
with open(file_path, 'w') as file:
    file.write('[')
    for item in aggregated_bnb_list[:-1]:
        file.write('"'+ str(item) + '"'+', ')
    file.write('"'+ str(item) + '"')
    file.write(']')

print(f'Text file created at {file_path}')
# Out:
# Text file created at output_bnb.txt

# %%
eth_df = df[df['deployedChains']=='0x1'].reset_index()

# %%
eth_df[['contract_addresses','_id','deployedChains']]
# Out:
#                                 contract_addresses                   _id  \
# 0     [0x78627c6798b9db51ca48dea1ff6ce0f5c5a66f81]  crystalfrogsofficial
# 1     [0x095dcca826ef15c8ac06088be7f5ff85c506191a]       hanazawakananft
# 2     [0xfe58fc763ba915013aee93c6f0890bfddbe03608]          beepboopbotz
# 3     [0x91673149ffae3274b32997288395d07a8213e41f]          junkyarddogs
# 4     [0x104f4986e647a5a3f4d1fdeae72e35f0c92ab484]         polarfrensnft
# ...                                            ...                   ...
# 1060  [0x9a38dec0590abc8c883d72e52391090e948ddf12]                everai
# 1061  [0xd24a7c412f2279b1901e591898c1e96c140be8c5]     patchworkkingdoms
# 1062  [0xa379cec69303e3ec0fea64d9298f126658276f63]           punks2hanzo
# 1063  [0x99c2546aebc070fb1f286a346ec4d25e70533474]              quadrums
# 1064  [0x33a4cfc925ad40e5bb2b9b2462d7a1a5a5da4476]                 pills
#
#      deployedChains
# 0               0x1
# 1               0x1
# 2               0x1
# ...

# %%
exploded_eth_df = eth_df.explode('contract_addresses')

# %%
aggregated_eth_list = exploded_eth_df['contract_addresses'].tolist()
aggregated_eth_list
# Out:
# ['0x78627c6798b9db51ca48dea1ff6ce0f5c5a66f81',
#  '0x095dcca826ef15c8ac06088be7f5ff85c506191a',
#  '0xfe58fc763ba915013aee93c6f0890bfddbe03608',
#  '0x91673149ffae3274b32997288395d07a8213e41f',
#  '0x104f4986e647a5a3f4d1fdeae72e35f0c92ab484',
#  '0x0f94778a99d649cdb0a21daff08dbd96f1d446ed',
#  '0x369443a0e62889646b338498d87316252bb5f8c7',
#  '0x78f3c6c28b6d70982f98678f5e09c3731c963152',
#  '0xef81c2c98cb9718003a89908e6bd1a5fa8a098a3',
#  '0x4ceae3c1c32471bfaee9420c922b32590790734c',
#  '0x61a073585e637aacde3135284054a47d42e19b50',
#  '0xe935e764da0f1a2597f9c1bf13a64515bff9f7d7',
#  '0x9ac70d7d63701e230446885776818d7734eb33f6',
#  '0x80416304142fa37929f8a4eee83ee7d2dac12d7c',
#  '0x76395f4cc1ad5a123b12c232ffb227e3d835392a',
#  '0x960b7a6bcd451c9968473f7bbfd9be826efd549a',
#  '0xf192502dc0a01728955a82a5b84631bf719c8ee2',
#  '0x616f2ac5dd4f760db693c21e9ca7a8aa962cf93b',
#  '0x41e8833eb409acb367e088d9655d79fa86aefcc2',
#  '0x4cd0ea8b1bdb5ab9249d96ccf3d8a0d3ada2bc76',
# ...

# %%
file_path = 'output_eth.txt'

# Write the list elements to the text file
with open(file_path, 'w') as file:
    file.write('[')
    for item in aggregated_eth_list[:-1]:
        file.write('"'+ str(item) + '"'+', ')
    file.write('"'+ str(item) + '"')
    file.write(']')

print(f'Text file created at {file_path}')
# Out:
# Text file created at output_eth.txt

# %%
polygon_df = df[df['deployedChains']=='0x89'].reset_index()

# %%
polygon_df[['contract_addresses','_id','deployedChains']]
# Out:
#                                    contract_addresses          _id  \
# 0        [0xdddddd4301a082e62e84e43f474f044423921918]     rhino.fi
# 1   [0x5de74546d3b86c8df7feec30253865e1149818c8, 0...     firebird
# 2   [0x6b0cc136f7babd971b5decd21690be65718990e2, 0...      apeswap
# 3   [0x12bb166f997146d3d33645146eedbc4a923195d7, 0...      clipper
# 4   [0xd682a62bd1df757616e68319720295ff7667a847, 0...        swaap
# 5   [0x93ea6ec350ace7473f7694d43dec2726a515e31a, 0...   aavegotchi
# 6   [0xc7d14a939ee0265beab7456394e50ccc6c665298, 0...       nasdex
# 7   [0xcc792e8b52b7a6717253b3260408953ac892539c, 0...   luchadores
# 8   [0xbf365ce9cfcb2d5855521985e351ba3bcf77fd3f, 0...        woofi
# 9        [0x668ad0ed2622c62e24f0d5ab6b6ac1b9d2cd4ac7]      jetswap
# 10       [0x5a75a093747b72a0e14056352751edf03518031d]      emiswap
# 11  [0x1948abc5400aa1d72223882958da3bec643fb4e5, 0...     dinoswap
# 12  [0x003c88bd94f503407224e7e64ace63eacffef3c6, 0...    quickswap
# ...

# %%
exploded_polygon_df = polygon_df.explode('contract_addresses')

# %%
aggregated_polygon_list = exploded_polygon_df['contract_addresses'].tolist()
aggregated_polygon_list
# Out:
# ['0xdddddd4301a082e62e84e43f474f044423921918',
#  '0x5de74546d3b86c8df7feec30253865e1149818c8',
#  '0xb31d1b1ea48ce4bf10ed697d44b747287e785ad4',
#  '0x6b0cc136f7babd971b5decd21690be65718990e2',
#  '0xbae5dc9b19004883d0377419fef3c2c8832d7d7b',
#  '0xd341a4a6bed64625d2d68765ba02cb611a1fd075',
#  '0xc959538a7229ac845492963bc58ffa57b34b621d',
#  '0xc95f21e17d081fed640e8831eadccd628f6ecf00',
#  '0xc96857cf18380c2e17f2be476e71833173c293cc',
#  '0xc98f707c46b3bfdcce4506ce786bacc347c8e6ab',
#  '0x5c8d727b265dbafaba67e050f2f739caeeb4a6f9',
#  '0x8822c32d504095be76f53fdf36419b504c52d43d',
#  '0xd311916ea04ceabaad9f5e781fed37f922860f30',
#  '0xd31c8df414189d3e8550fb108ee65d2607bc9c89',
#  '0xd3b1aeb46107a3be10747197e8c8b1eb57c73bde',
#  '0xd3b9b1aa91bd8ea3e41c933e5fc8fe5c7e00d762',
#  '0xd4295cbcac3715b5167e738837e2ccde0b32a579',
#  '0xd433b56d4468c2c4cec80e2d331f0b24ecbcfb31',
#  '0xd44cd46d4ba2cc243c9751a9ffcce860c6bdd00f',
#  '0x4f78b064157984d5f9f2dcb9fe19ac2464e0a865',
# ...

# %%
file_path = 'output_polygon.txt'

# Write the list elements to the text file
with open(file_path, 'w') as file:
    file.write('[')
    for item in aggregated_polygon_list[:-1]:
        file.write('"'+ str(item) + '"'+', ')
    file.write('"'+ str(item) + '"')
    file.write(']')

print(f'Text file created at {file_path}')
# Out:
# Text file created at output_polygon.txt

# %%
print("BNB: " + str(len(aggregated_bnb_list)))
print("ETH: " + str(len(aggregated_eth_list)))
print("POLYGON: " + str(len(aggregated_polygon_list)))
# Out:
# BNB: 8950
# ETH: 7738
# POLYGON: 35489

# %%
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient('mongodb://etlReaderAnalysis:etl_reader_analysis__Gr2rEVBXyPWzIrP@34.126.84.83:27017,34.142.204.61:27017,34.142.219.60:27017/')
db = client["blockchain_etl"]  
collection = db["transactions"] 


def filter_transaction(aggregated_list, chain):
    # Set the batch size
    if chain == "bnb":
        db = client["blockchain_etl"]  
    elif chain == "eth":
        db = client["ethereum_blockchain_etl"]
    else:
        db = client["polygon_blockchain_etl"]
    collection = db["transactions"] 
    batch_size = 25

    # Initialize variables
    result = []
    i = 0

    while i < len(aggregated_list):
        start = i
        if i + batch_size < len(aggregated_list):
            end = i + batch_size
        else:
            end = len(aggregated_list)
        # Define the aggregation pipeline
        try:
            pipeline = [
                {"$match": {"to_address": {"$in": aggregated_list[start:end]}}},
                {"$group": {"_id": "$to_address", "recordCount": {"$sum": 1}}},
                {"$sort": {"recordCount": -1}}
            ]

            # Use find with batch_size and maxTimeMS
            cursor = collection.aggregate(pipeline, batchSize=batch_size, maxTimeMS=60000)

            # Extend the result with the cursor
            result.extend(list(c)
            print("Done {}%".format(end / len(aggregated_list) * 100))

        except:
            # Handle the timeout exception
            print(f"Timeout occurred for batch {start}-{end}, continuing to the next batch.")
            print(start, end)

        i += batch_size


    # Convert the cursor result to a DataFrame
    df = pd.DataFrame(result)

    # Print or process the DataFrame
    return df

# %%
bnb_trans_df = filter_transaction(aggregated_bnb_list)
bnb_trans_df
# Out:
# 0 25
# Done 0.27932960893854747%
# 25 50
# Done 0.5586592178770949%
# 50 75
# Done 0.8379888268156425%
# 75 100
# Done 1.1173184357541899%
# 100 125
# Done 1.3966480446927374%
# 125 150
# Done 1.675977653631285%
# 150 175
# Done 1.9553072625698324%
# 175 200
# Done 2.2346368715083798%
# 200 225
# Done 2.5139664804469275%
# 225 250
# Done 2.793296089385475%
# 250 275
# Done 3.072625698324022%
# 275 300
# Done 3.35195530726257%
# 300 325
# Done 3.6312849162011176%
# Timeout occurred for batch 325-350, continuing to the next batch.
# 350 375
# Done 4.189944134078212%
# 375 400
# Done 4.4692737430167595%
# 400 425
# Done 4.748603351955307%
# 425 450
# Done 5.027932960893855%
# 450 475
# Done 5.307262569832402%
# 475 500
# Done 5.58659217877095%
# 500 525
# Done 5.865921787709497%
# 525 550
# Done 6.145251396648044%
# 550 575
# Done 6.424581005586592%
# 575 600
# Done 6.70391061452514%
# 600 625
# Done 6.983240223463687%
# 625 650
# Done 7.262569832402235%
# 650 675
# ...

# %%
bnb_trans_df.sort_values(by="recordCount", ascending=False).head(20)
# Out:
#                                              _id  recordCount
# 3834  0x7e277614644409a69ea70df5cfcb114e4a51676d        97750
# 3818  0x7e277614644409a69ea70df5cfcb114e4a51676d        97750
# 1434  0x7bd46f6da97312ac2dbd1749f82e202764c0b914        71507
# 3165  0x2b30c317cedfb554ec525f85e79538d59970beb0        51127
# 2837  0xbf1fc29668e5f5eaa819948599c9ac1b1e03e75f        31919
# 3400  0xe730c7b7470447ad4886c763247012dfd233baff        30876
# 3691  0xdb6c248902ad2722a5e01e9689824c28bd0a5f75        18356
# 191   0x223740a259e461abee12d84a9fff5da69ff071dd        17958
# 1048  0x51e6d27fa57373d8d4c256231241053a70cb1d93        17825
# 295   0xaf9aa53146c5752bf6068a84b970e9fbb22a87bc        16026
# 3516  0x36ae10a4d16311959b607ee98bc4a8a653a33b1f        15423
# 918   0x451bcf562a4d747da3455bbaface988d56da6d83        14266
# 3190  0xda8ceb724a06819c0a5cdb4304ea0cb27f8304cf        13567
# 2076  0xc087c78abac4a0e900a327444193dbf9ba69058e        13265
# ...

# %%
eth_trans_df = filter_transaction(aggregated_eth_list, "eth")
eth_trans_df
# Out:
# 0 25
# Done 0.32308089945722407%
# 25 50
# Done 0.6461617989144481%
# 50 75
# Done 0.9692426983716723%
# 75 100
# Done 1.2923235978288963%
# 100 125
# Done 1.6154044972861203%
# 125 150
# Done 1.9384853967433446%
# 150 175
# Done 2.2615662962005687%
# 175 200
# Done 2.5846471956577926%
# 200 225
# Done 2.907728095115017%
# 225 250
# Done 3.2308089945722407%
# 250 275
# Done 3.5538898940294645%
# 275 300
# Done 3.8769707934866893%
# 300 325
# Done 4.200051692943913%
# 325 350
# Done 4.523132592401137%
# 350 375
# Done 4.846213491858362%
# 375 400
# Done 5.169294391315585%
# 400 425
# Done 5.492375290772809%
# 425 450
# Done 5.815456190230034%
# 450 475
# Done 6.138537089687258%
# 475 500
# Done 6.461617989144481%
# 500 525
# Done 6.784698888601707%
# 525 550
# Done 7.107779788058929%
# 550 575
# Done 7.430860687516154%
# 575 600
# Done 7.7539415869733785%
# 600 625
# Done 8.077022486430602%
# 625 650
# Done 8.400103385887826%
# 650 675
# Done 8.72318428534505%
# 675 700
# ...

# %%
eth_trans_df.sort_values(by="recordCount", ascending=False).head(20)
# Out:
#                                              _id  recordCount
# 343   0x2a0c0dbecc7e4d658f48e01e3fa353f44050c208      3437437
# 1750  0x06012c8cf97bead5deae237070f9587f8e7a266d      2715217
# 1160  0x03f7724180aa6b939894b5ca4314783b0b36b329      1426883
# 1751  0xb1690c08e213a35ed9bab7b318de14420fb57d8c       766632
# 170   0xbbbbca6a901c926f240b89eacb641d8aec7aeafd       624273
# 528   0xdef171fe48cf0115b1d80b88dc8eab59176fee57       610285
# 503   0xdef171fe48cf0115b1d80b88dc8eab59176fee57       610285
# 570   0x03f34be1bf910116595db1b11e9d1b2ca5d59659       467759
# 1236  0x9813037ee2218799597d83d4a5b6f3b6778218d9       406797
# 571   0xdc6c91b569c98f9f6f74d90f9beff99fdaf4248b       328813
# 1511  0x1e0447b19bb6ecfdae1e4ae1694b0c3659614e4e       295976
# 1682  0x8ce9137d39326ad0cd6491fb5cc0cba0e089b6a9       260069
# 1983  0xfaafdc07907ff5120a76b34b731b278c38d6043c       238114
# 417   0xba100000625a3754423978a60c9317c58a424e3d       217417
# ...

# %%
eth_trans_df_sorted = eth_trans_df.sort_values(by='recordCount', ascending=False)

# Select the top 3 rows and extract the 'A' column
top_3_eth = eth_trans_df_sorted.head(3)['_id'].tolist()

# Print or use the list of elements from column A with the top 3 highest values in column B
print(top_3_eth)
# Out:
# ['0x2a0c0dbecc7e4d658f48e01e3fa353f44050c208', '0x06012c8cf97bead5deae237070f9587f8e7a266d', '0x03f7724180aa6b939894b5ca4314783b0b36b329']

# %%
polygon_trans_df = filter_transaction(aggregated_polygon_list, "polygon")
polygon_trans_df
# Out:
# Timeout occurred for batch 0-25, continuing to the next batch.
# 25 50
# Done 0.14088872608413874%
# 50 75
# Done 0.2113330891262081%
# 75 100
# Done 0.2817774521682775%
# 100 125
# Done 0.3522218152103469%
# 125 150
# Done 0.4226661782524162%
# 150 175
# Done 0.4931105412944856%
# 175 200
# Done 0.563554904336555%
# 200 225
# Done 0.6339992673786243%
# 225 250
# Done 0.7044436304206938%
# 250 275
# Done 0.774887993462763%
# 275 300
# Done 0.8453323565048324%
# 300 325
# Done 0.9157767195469019%
# 325 350
# Done 0.9862210825889712%
# 350 375
# Done 1.0566654456310407%
# 375 400
# Done 1.12710980867311%
# 400 425
# Done 1.1975541717151794%
# 425 450
# Done 1.2679985347572487%
# 450 475
# Done 1.3384428977993181%
# 475 500
# Done 1.4088872608413876%
# 500 525
# Done 1.4793316238834568%
# 525 550
# Done 1.549775986925526%
# 550 575
# Done 1.6202203499675956%
# 575 600
# Done 1.6906647130096648%
# 600 625
# Done 1.7611090760517343%
# 625 650
# Done 1.8315534390938037%
# 650 675
# ...

# %%
polygon_trans_df.sort_values(by="recordCount", ascending=False).head(20)
# Out:
#                                               _id  recordCount
# 4711   0xb5c064f955d8e7f38fe0460c556a72987494ee17        89013
# 1695   0x369582d2010b6ed950b571f4101e3bb9b554876f        58471
# 1302   0x2bbe0f728f4d5821f84eee0432d2a4be7c0cb7fc        51382
# 2233   0x3c1f53fed2238176419f8f897aec8791c499e3c8        44047
# 9842   0x019ba0325f1988213d448b3472fa1cf8d07618d7        43292
# 555    0x160532d2536175d65c03b97b0630a9802c274dad        43193
# 10329  0x654def7daa4e51c940ef664c7ab27fb4c257970a        31781
# 7753   0xd26e16f5a9dfb9fe32db7f6386402b8aae1a5dd7        28157
# 1595   0x289cf2b63c5edeeeab89663639674d9233e8668e        23491
# 9468   0xff22bf1f778bcd6741d823b077285533ec582f78        22266
# 6416   0x9a8b2601760814019b7e6ee0052e25f1c623d1e6        22133
# 8430   0xdc9232e2df177d7a12fdff6ecbab114e2231198d        21726
# 8927   0xf04adbf75cdfc5ed26eea4bbbb991db002036bdd        19539
# 4087   0x6405ebc22cb0899fc21f414085ac4044b4721a0d        18871
# ...

# %%
polygon_trans_df_sorted = polygon_trans_df.sort_values(by='recordCount', ascending=False)

# Select the top 3 rows and extract the 'A' column
top_3_polygon = polygon_trans_df_sorted.head(3)['_id'].tolist()

# Print or use the list of elements from column A with the top 3 highest values in column B
print(top_3_polygon)
# Out:
# ['0xb5c064f955d8e7f38fe0460c556a72987494ee17', '0x369582d2010b6ed950b571f4101e3bb9b554876f', '0x2bbe0f728f4d5821f84eee0432d2a4be7c0cb7fc']

# %%
# Define the query
db_pol = client["polygon_blockchain_etl"]  
collection_pol = db_pol["transactions"] 

query = {"to_address": {"$in": top_3_polygon}}

# Find documents matching the query
cursor = collection_pol.find(query)

# Initialize variables
result = []

# Iterate over the cursor
for document in cursor:
    result.append(document)

# Convert the result to a DataFrame
df = pd.DataFrame(result)

# Print or process the DataFrame
df
# Out:
#                                                       _id         type  \
# 0       transaction_0xf831150fb5992e5314f5b035cb228f37...  transaction
# 1       transaction_0x99a7a25613e77425152bc17ba8a6d1dd...  transaction
# 2       transaction_0x47cdcf2320f56b4dbcdfadd5529c2255...  transaction
# 3       transaction_0xda5335e052800a9c9fb1da1e5e8d7a10...  transaction
# 4       transaction_0x166d92447ed91415611482c7a6c63465...  transaction
# ...                                                   ...          ...
# 198873  transaction_0x5cc0cab1200a2d47cdbb78755fcaaead...  transaction
# 198874  transaction_0x71b2424d03a2830e334f95af96263e50...  transaction
# 198875  transaction_0xe73709825572c6e3b3308f0d99f92389...  transaction
# 198876  transaction_0x167a1f66582dd115c7c653af89f47e84...  transaction
# 198877  transaction_0xcbe8df9456bfb13c7fcd460657e15f11...  transaction
#
#                                                      hash  nonce  \
# ...

# %%
from_add = list(set(df["from_address"].tolist()))
len(from_add)
# Out:
# 92539

# %%
bnb_trans_df_sorted = bnb_trans_df.sort_values(by='recordCount', ascending=False)

# Select the top 3 rows and extract the 'A' column
top_3_bnb = bnb_trans_df_sorted.head(3)['_id'].tolist()

# Print or use the list of elements from column A with the top 3 highest values in column B
print(top_3_bnb)
# Out:
# ['0x7e277614644409a69ea70df5cfcb114e4a51676d', '0x7e277614644409a69ea70df5cfcb114e4a51676d', '0x7bd46f6da97312ac2dbd1749f82e202764c0b914']

# %%
# Define the query
query = {"to_address": {"$in": top_3_bnb}}

# Find documents matching the query
cursor = collection.find(query)

# Initialize variables
result = []

# Iterate over the cursor
for document in cursor:
    result.append(document)

# Convert the result to a DataFrame
df = pd.DataFrame(result)

# Print or process the DataFrame
print(df)
# Out:
#                                                       _id         type  \
# 0       transaction_0xd5372bf82aa51a9d15454141e8e4bee1...  transaction
# 1       transaction_0x5b493695e6dd3998c49425502e28f232...  transaction
# 2       transaction_0x3eb69af2404b62382b3d95bcae2d09e5...  transaction
# 3       transaction_0xa7d45cf9ad68dc85b07cb3c04fabefa7...  transaction
# 4       transaction_0xcff4f494aed0edb7d3d18abca8215cb8...  transaction
# ...                                                   ...          ...
# 169252  transaction_0xe26cdda005b9817bfd2eed0344675b63...  transaction
# 169253  transaction_0x78a54e0b2c1cee121ec9e752278bc433...  transaction
# 169254  transaction_0x64533ffb100ee02d6d4518b3dcc87f30...  transaction
# 169255  transaction_0x3c64a6913ff5e041361cae5003b46f51...  transaction
# 169256  transaction_0x131ab7d14effe59aa5e091724e2b06ff...  transaction
#
#                                                      hash  nonce  \
# ...

# %%
df
# Out:
#                                                       _id         type  \
# 0       transaction_0xd5372bf82aa51a9d15454141e8e4bee1...  transaction
# 1       transaction_0x5b493695e6dd3998c49425502e28f232...  transaction
# 2       transaction_0x3eb69af2404b62382b3d95bcae2d09e5...  transaction
# 3       transaction_0xa7d45cf9ad68dc85b07cb3c04fabefa7...  transaction
# 4       transaction_0xcff4f494aed0edb7d3d18abca8215cb8...  transaction
# ...                                                   ...          ...
# 169252  transaction_0xe26cdda005b9817bfd2eed0344675b63...  transaction
# 169253  transaction_0x78a54e0b2c1cee121ec9e752278bc433...  transaction
# 169254  transaction_0x64533ffb100ee02d6d4518b3dcc87f30...  transaction
# 169255  transaction_0x3c64a6913ff5e041361cae5003b46f51...  transaction
# 169256  transaction_0x131ab7d14effe59aa5e091724e2b06ff...  transaction
#
#                                                      hash  nonce  \
# ...

# %%
from_add = list(set(df["from_address"].tolist()))
len(from_add)
# Out:
# 31481

# %%
import psycopg2


conn = psycopg2.connect(
    database="postgres",
    host="34.126.75.56",
    port="5432",
    user="student_token_transfer",
    password="svbk_2023"
)

cur = conn.cursor()

# %%
cur.execute("ROLLBACK")
conn.commit()

# %%
# List of values
res = []
batch_size = 25
i = 0

while i < len(from_add):
    start = i
    if i + batch_size < len(from_add):
        end = i + batch_size
    else:
        end = len(from_add)
    print(start, end)
    # Define the aggregation pipeline
    try:
       # SQL query with placeholders and LIMIT clause
        sql_query = """
            SELECT *
            FROM chain_0x89.token_transfer
            WHERE from_address IN %s AND to_address IN %s;
        """

        # Execute the query with the list as a parameter
        cur.execute(sql_query, (tuple(from_add[start:end]), tuple(from_add[start:end])))

        # Fetch all the rows
        rows = cur.fetchall()
        
        res.extend(rows)
        if i%2000 == 0:
            print("Done {}%".format(end / len(from_add) * 100))
            print("Size = " + str(len(res)))

    except:
        # Handle the timeout exception
        print(f"Timeout occurred for batch {start}-{end}, continuing to the next batch.")

    i += batch_size

# Create a DataFrame from the result
columns = [desc[0] for desc in cur.description]
df_trans = pd.DataFrame(res, columns=columns)
# Out:
# 0 25
# Done 0.027015636650493304%
# Size = 0
# 25 50
# 50 75
# 75 100
# 100 125
# 125 150
# 150 175
# 175 200
# 200 225
# 225 250
# 250 275
# 275 300
# 300 325
# 325 350
# 350 375
# 375 400
# 400 425
# 425 450
# 450 475
# 475 500
# 500 525
# 525 550
# 550 575
# 575 600
# 600 625
# 625 650
# 650 675
# 675 700
# 700 725
# 725 750
# 750 775
# 775 800
# 800 825
# 825 850
# 850 875
# 875 900
# 900 925
# 925 950
# 950 975
# 975 1000
# 1000 1025
# 1025 1050
# 1050 1075
# 1075 1100
# 1100 1125
# 1125 1150
# 1150 1175
# 1175 1200
# 1200 1225
# 1225 1250
# 1250 1275
# 1275 1300
# 1300 1325
# 1325 1350
# 1350 1375
# 1375 1400
# 1400 1425
# 1425 1450
# 1450 1475
# 1475 1500
# 1500 1525
# 1525 1550
# 1550 1575
# 1575 1600
# 1600 1625
# 1625 1650
# 1650 1675
# 1675 1700
# 1700 1725
# 1725 1750
# 1750 1775
# 1775 1800
# 1800 1825
# 1825 1850
# 1850 1875
# 1875 1900
# 1900 1925
# 1925 1950
# 1950 1975
# 1975 2000
# 2000 2025
# Done 2.188266568689958%
# Size = 4
# 2025 2050
# 2050 2075
# 2075 2100
# ...

# %%
df_trans
# Out:
#                                contract_address  \
# 0    0x2fe8733dcb25bfbba79292294347415417510067
# 1    0x3a58a54c066fdc0f2d55fc9c89f0415c92ebf3c4
# 2    0x3a58a54c066fdc0f2d55fc9c89f0415c92ebf3c4
# 3    0x7ceb23fd6bc0add59e62ac25578270cff1b9f619
# 4    0x3c499c542cef5e3811e1192ce70d8cc03d5c3359
# ..                                          ...
# 494  0xb33eaad8d922b1083446dc23f610c2567fb5180f
# 495  0xb33eaad8d922b1083446dc23f610c2567fb5180f
# 496  0xb33eaad8d922b1083446dc23f610c2567fb5180f
# 497  0xb5c064f955d8e7f38fe0460c556a72987494ee17
# 498  0xb5c064f955d8e7f38fe0460c556a72987494ee17
#
#                                       transaction_hash  log_index  \
# 0    0x64d3d39878b727ac3197ab440454eccba177860f61e1...        103
# 1    0x7a4567afc7b0679249f72048cdeed5d61fa63c365d93...        518
# 2    0x1abcc7ec3a5c12aad4ed743123ecfd2b119522c891a0...        233
# 3    0xa30cb98ce65d019db3aa4d24b404b007c15b36f0a73d...        229
# ...

# %%
df_trans.to_json('top3_polygon_transfer.json', orient='records')

# %%
# # List of values
# res = []

# with conn.cursor(name='custom_cursor') as cursor:
    
#     cursor.itersize = 1000 # chunk size
        
#     # SQL query with placeholders and LIMIT clause
#     sql_query = """
#         SELECT *
#         FROM chain_0x38.token_transfer
#         WHERE from_address IN %s AND to_address IN %s;
#     """

#     # Execute the query with the list as a parameter
#     cursor.execute(sql_query, (tuple(from_add), tuple(from_add)))

#     # Fetch all the rows
#     rows = cursor.fetchall()
    
#     res.extend(rows)
#     print("1 iter done")

# # Create a DataFrame from the result
# columns = [desc[0] for desc in cur.description]
# df_trans = pd.DataFrame(res, columns=columns)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-8c4105c766af> in <module>
#      17
#      18     # Fetch all the rows
# ---> 19     rows = cursor.fetchall()
#      20
#      21     res.extend(rows)
#
# c:\users\admin\appdata\local\programs\python\python38\lib\encodings\utf_8.py in decode(input, errors)
#      13 encode = codecs.utf_8_encode
#      14
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_8_decode(input, errors, True)
#      17
#
# KeyboardInterrupt:

# %%
df_trans

# %%
# Save the DataFrame to a JSON file
df_trans.to_json('output.json', orient='records')

# %%
# aggregated_bnb_list_a = list(set(aggregated_bnb_list))
# print(len(aggregated_bnb_list_a), len(aggregated_bnb_list))
# aggregated_eth_list_a = list(set(aggregated_eth_list))
# print(len(aggregated_eth_list_a), len(aggregated_eth_list))
# aggregated_polygon_list_a = list(set(aggregated_polygon_list))
# print(len(aggregated_polygon_list_a), len(aggregated_polygon_list))
# Out:
# 8939 8950
# 7720 7738
# 35477 35489

# %%
# from pymongo import MongoClient

# # Connect to MongoDB
# client = MongoClient('mongodb://etlReaderAnalysis:etl_reader_analysis__Gr2rEVBXyPWzIrP@34.126.84.83:27017,34.142.204.61:27017,34.142.219.60:27017/')
# db = client["blockchain_etl"]  # Replace with your actual database name
# collection = db["transactions"]  # Replace with your actual collection name

# # Set the batch size
# batch_size = 100000

# # Initialize variables
# skip = 0
# result = []

# # Define the aggregation pipeline
# pipeline = [
#     {"$match": {"to_address": {"$in": aggregated_bnb_list[332:333]}}},
#     {"$group": {"_id": "$to_address", "recordCount": {"$sum": 1}}}
# ]

# # Use find with batch_size
# cursor = collection.aggregate(pipeline, batchSize=batch_size)

# # Convert the cursor result to a DataFrame
# df = pd.DataFrame(list(cursor))

# # Print or process the DataFrame
# print(df)

# %%
aggregated_bnb_list[331]
# Out:
# '0x7dae51bd3e3376b8c7c4900e9107f12be3af1ba8'
